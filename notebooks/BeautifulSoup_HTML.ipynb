# %% [markdown]
# This code example (for Python 3) has been taken from Wikipedia, the free encyclopedia, s.v. [Beautiful Soup (HTML parser)](https://en.wikipedia.org/wiki/Beautiful_Soup_(HTML_parser))

# %%
# Python 3
# Anchor extraction from html document
from bs4 import BeautifulSoup
import urllib.request

# %%
with urllib.request.urlopen('https://en.wikipedia.org/wiki/Main_Page') as response:
    webpage = response.read()
    soup = BeautifulSoup(webpage, 'html.parser')
    for anchor in soup.find_all('a'):
        print(anchor.get('href', '/'))
# Out:
# /
# #mw-head
# #p-search
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Wikipedia:Introduction
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/Portal:Arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Portal:Contents/Portals
# /wiki/File:Hurricane_Hazel_--_Lawrence_Avenue.jpg
# /wiki/Hurricane_Hazel
# /wiki/Tropical_cyclone
# /wiki/1954_Atlantic_hurricane_season
# /wiki/Tropical_cyclone_naming
# /wiki/National_Weather_Service
# /wiki/Haiti
# /wiki/North_Carolina
# /wiki/Calabash,_North_Carolina
# /wiki/Saffir%E2%80%93Simpson_scale#Category_4
# /wiki/Myrtle_Beach,_South_Carolina
# /wiki/Extratropical_cyclone
# /wiki/Toronto
# /wiki/Canadian_dollar
# /wiki/List_of_retired_Atlantic_hurricane_names
# /wiki/Atlantic_hurricane
# /wiki/Hurricane_Hazel
# /wiki/Malagasy_mountain_mouse
# ...
