# %%
# Python 3
# Anchor extraction from html document
from bs4 import BeautifulSoup

import urllib.request

# %%
with urllib.request.urlopen('https://stackoverflow.com/feeds/') as response:
    markup = response.read()
    soup = BeautifulSoup(markup, "xml")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-2-5f267585cca2> in <module>
#       1 with urllib.request.urlopen('https://stackoverflow.com/feeds/') as response:
#       2     markup = response.read()
# ----> 3     soup = BeautifulSoup(markup, "xml")
#
# /usr/lib/python3/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     154                     "Couldn't find a tree builder with the features you "
#     155                     "requested: %s. Do you need to install a parser library?"
# --> 156                     % ",".join(features))
#     157             builder = builder_class()
#     158             if not (original_features == builder.NAME or
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: xml. Do you need to install a parser library?

# %%
with open("stackoverflow.com_feeds.xml") as fp:
    soup = BeautifulSoup(fp)
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
with open("stackoverflow.com_feeds.xml") as response:
    markup = response.read()
    soup = BeautifulSoup(markup)

# %%
url = 'https://stackoverflow.com/feeds/'
import urllib
from bs4 import BeautifulSoup

# %%
with urllib.request.urlopen(url) as response:
    soup = BeautifulSoup(response.read(), "lxml-xml")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-6-126a61121828> in <module>
#       1 with urllib.request.urlopen(url) as response:
# ----> 2     soup = BeautifulSoup(response.read(), "lxml-xml")
#
# /usr/lib/python3/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     154                     "Couldn't find a tree builder with the features you "
#     155                     "requested: %s. Do you need to install a parser library?"
# --> 156                     % ",".join(features))
#     157             builder = builder_class()
#     158             if not (original_features == builder.NAME or
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml-xml. Do you need to install a parser library?

# %%
for entry in soup.find_all('entry'):
    print(entry)
# Out:
# <entry>
#         <id>https://stackoverflow.com/q/52814190</id>
#         <re:rank scheme="https://stackoverflow.com">0</re:rank>
#         <title type="text">How to get the URI of a file stored in a folder created with context.getDir(directoryName, Context.MODE_PRIVATE)?</title>
#             <category scheme="https://stackoverflow.com/tags" term="android">
#             <category scheme="https://stackoverflow.com/tags" term="uri">
#             <category scheme="https://stackoverflow.com/tags" term="android-fileprovider">
#         <author>
#             <name>blade</name>
#             <uri>https://stackoverflow.com/users/3753336</uri>
#         </author>
#         <link href="https://stackoverflow.com/questions/52814190/how-to-get-the-uri-of-a-file-stored-in-a-folder-created-with-context-getdirdire" rel="alternate"/>
#         <published>2018-10-15T10:00:03Z</published>
#         <updated>2018-10-15T10:00:03Z</updated>
#         <summary type="html">
#
#
# ...
